# %%
#importing necessary libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
# %matplotlib inline

from xgboost import XGBClassifier
from sklearn.ensemble import (AdaBoostClassifier,
                              BaggingClassifier,
                              GradientBoostingClassifier,
                              RandomForestClassifier,
                              )
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (classification_report,
                             confusion_matrix,
                             accuracy_score,
                             recall_score,
                             precision_score,
                             f1_score,
                             make_scorer
                             )

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler


import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset
data= pd.read_csv("BankChurners.csv")

# %%
data_bkp = data.copy()

# %%
data.head() #printing first 5 rows
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School            NaN  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
data.shape #Printing number of columns and rows
# Out:
# (10127, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           8608 non-null   object
#  6   Marital_Status            9378 non-null   object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %% [markdown]
# ##### Observations:
#
# Except for 2 columns, remaining columns doesn't have null values. 6 columns are objects and remaining columns are numeric columns

# %%
#Check for duplicate values

data.duplicated().value_counts()
# Out:
# False    10127
# Name: count, dtype: int64

# %% [markdown]
# There are no duplicate entries

# %%
#Checking for columns with null values

data.isna().sum()
# Out:
# CLIENTNUM                      0
# Attrition_Flag                 0
# Customer_Age                   0
# Gender                         0
# Dependent_count                0
# Education_Level             1519
# Marital_Status               749
# Income_Category                0
# Card_Category                  0
# Months_on_book                 0
# Total_Relationship_Count       0
# Months_Inactive_12_mon         0
# Contacts_Count_12_mon          0
# Credit_Limit                   0
# Total_Revolving_Bal            0
# Avg_Open_To_Buy                0
# Total_Amt_Chng_Q4_Q1           0
# Total_Trans_Amt                0
# Total_Trans_Ct                 0
# Total_Ct_Chng_Q4_Q1            0
# Avg_Utilization_Ratio          0
# dtype: int64

# %% [markdown]
# 2 columns have null values. These will be imputed with appropriate values.

# %%
data.describe().T #Summary of numeric column
# Out:
#                             count          mean           std          min  \
# CLIENTNUM                 10127.0  7.391776e+08  3.690378e+07  708082083.0
# Customer_Age              10127.0  4.632596e+01  8.016814e+00         26.0
# Dependent_count           10127.0  2.346203e+00  1.298908e+00          0.0
# Months_on_book            10127.0  3.592841e+01  7.986416e+00         13.0
# Total_Relationship_Count  10127.0  3.812580e+00  1.554408e+00          1.0
# Months_Inactive_12_mon    10127.0  2.341167e+00  1.010622e+00          0.0
# Contacts_Count_12_mon     10127.0  2.455317e+00  1.106225e+00          0.0
# Credit_Limit              10127.0  8.631954e+03  9.088777e+03       1438.3
# Total_Revolving_Bal       10127.0  1.162814e+03  8.149873e+02          0.0
# Avg_Open_To_Buy           10127.0  7.469140e+03  9.090685e+03          3.0
# Total_Amt_Chng_Q4_Q1      10127.0  7.599407e-01  2.192068e-01          0.0
# ...

# %% [markdown]
# ##### Observations:
#
# 1. CLIENTNUM: This unique identifier is not relevant for analysis and will be excluded from further consideration.
# 2. Customer Age: The dataset includes individuals ranging from 26 to 73 years old, with an average age of 46 years.
# 3. Dependent Count: The average number of dependents per customer is 2.3, with a minimum of 0 and a maximum of 5 dependents.
# 4. Months_on_Book: The average customer tenure is 35.9 months, ranging from 13 to 56 months.
# 5. Total Relationship Count: Customers have an average of 3.8 products with the bank, with a minimum of 1 and a maximum of 6 products.
# 6. Months Inactive in Last 12 Months: On average, customers were inactive for 2.3 months within the last 12-month period, with a minimum of 0 months and a maximum of 6 months of inactivity.
# 7. Contact Count in Last 12 Months: The average number of customer contacts within the last 12 months is 2.4, ranging from 0 to 6 contacts.
# 8. Credit Limit: The credit limit exhibits a wide range, from $1,438 to $34,516, with an average of $8,632.
# 9. Total Revolving Balance: The average revolving balance is $1,163, with a minimum of $0 and a maximum of $2,517.
# 10. Average Open to Buy: The average available credit (open to buy) is $7,469, ranging from $3 to $34,516.
# 11. Quarterly Spending Change: The ratio of Q4 spending to Q1 spending (Total_Amt_Chng_Q4_Q1) has an average of 0.76, ranging from 0 to 3.397.
# 12. Total Transaction Amount: The total transaction amount for customers ranges from $510 to $18,484, with an average of $4,404.
# 13. Total Transaction Count: The average number of transactions per customer is 64.8, ranging from 10 to 139 transactions.
# 14. Quarterly Transaction Count Change: The ratio of Q4 transaction count to Q1 transaction count (Total_Ct_Chng_Q4_Q1) has an average of 0.71, ranging from 0 to 3.71.
# 15. Average Utilization Ratio: The average credit utilization ratio is 27.5%, indicating that customers, on average, utilize 27.5% of their available credit, with a minimum of 0% and a maximum of 99.9% utilization.

# %%
data.describe(include=["object"]).T #Summary of objects
# Out:
#                  count unique                top  freq
# Attrition_Flag   10127      2  Existing Customer  8500
# Gender           10127      2                  F  5358
# Education_Level   8608      6           Graduate  3128
# Marital_Status    9378      3            Married  4687
# Income_Category  10127      6     Less than $40K  3561
# Card_Category    10127      4               Blue  9436

# %% [markdown]
# ##### Observations:
#
# 1. Attrition Flag: This binary variable indicates whether a customer is an "Existing Customer" or has "Attrited".
# 2. Gender: The dataset includes both male and female customers, with females being the more prevalent gender.
# 3. Education Level: The most common education level among customers is "Graduate," although missing values are present. To prevent data leakage, these missing values will be imputed after splitting the data into training, validation, and test sets.
# 4. Marital Status: "Married" is the most common marital status among customers. Missing values exist and will be imputed using appropriate techniques after data splitting to avoid data leakage.
# 5. Income Category: The majority of customers fall into the "Less than 40k" income category.
# 6. Card Category: The "Blue" card category is the most prevalent among customers.

# %%
data['Attrition_Flag'].value_counts(1) #Checking the target column
# Out:
# Attrition_Flag
# Existing Customer    0.83934
# Attrited Customer    0.16066
# Name: proportion, dtype: float64

# %% [markdown]
# 83.9% of customer exists.

# %% [markdown]
# ### Data Pre-processing

# %%
#Dropping the first column as it doesn't add value for model building

data = data.drop('CLIENTNUM', axis=1)

# %%
#Encoding Existing and Attrited customers to 1 and 0
data["Attrition_Flag"].replace("Existing Customer", 1, inplace=True)
data["Attrition_Flag"].replace("Attrited Customer", 0, inplace=True)

# %%
data.head()
# Out:
#    Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0               1            45      M                3     High School
# 1               1            49      F                5        Graduate
# 2               1            51      M                3        Graduate
# 3               1            40      F                4     High School
# 4               1            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3            NaN  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %%
#Checking income category column

data['Income_Category'].value_counts()
# Out:
# Income_Category
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# abc               1112
# $120K +            727
# Name: count, dtype: int64

# %% [markdown]
# 1112 entries are with category abc

# %%
#replace abc entries with nan
data['Income_Category'].replace('abc', np.nan, inplace=True)

# %%
#list of object columns
obj_cols = [
    'Attrition_Flag',
    'Gender',
    'Education_Level',
    'Marital_Status',
    'Card_Category',
    'Income_Category'
]

# Converting Object columns to "category" data type.
data[obj_cols] = data[obj_cols].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition_Flag            10127 non-null  category
#  1   Customer_Age              10127 non-null  int64
#  2   Gender                    10127 non-null  category
#  3   Dependent_count           10127 non-null  int64
#  4   Education_Level           8608 non-null   category
#  5   Marital_Status            9378 non-null   category
#  6   Income_Category           9015 non-null   category
#  7   Card_Category             10127 non-null  category
#  8   Months_on_book            10127 non-null  int64
#  9   Total_Relationship_Count  10127 non-null  int64
#  10  Months_Inactive_12_mon    10127 non-null  int64
#  11  Contacts_Count_12_mon     10127 non-null  int64
#  12  Credit_Limit              10127 non-null  float64
# ...

# %%
data.isna().sum()
# Out:
# Attrition_Flag                 0
# Customer_Age                   0
# Gender                         0
# Dependent_count                0
# Education_Level             1519
# Marital_Status               749
# Income_Category             1112
# Card_Category                  0
# Months_on_book                 0
# Total_Relationship_Count       0
# Months_Inactive_12_mon         0
# Contacts_Count_12_mon          0
# Credit_Limit                   0
# Total_Revolving_Bal            0
# Avg_Open_To_Buy                0
# Total_Amt_Chng_Q4_Q1           0
# Total_Trans_Amt                0
# Total_Trans_Ct                 0
# Total_Ct_Chng_Q4_Q1            0
# Avg_Utilization_Ratio          0
# dtype: int64

# %% [markdown]
# ### Exploratory data analysis

# %%
# function to plot a boxplot and a histogram along the same scale. 

"Referred from a previous project"


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a triangle will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
# function to create labeled barplots

"Referred from previous project"

def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
# function to plot stacked bar chart

def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower left", frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
### Function to plot distributions

def distribution_plot_wrt_target(data, predictor, target):

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))

    target_uniq = data[target].unique()

    axs[0, 0].set_title("Distribution of target for target=" + str(target_uniq[0]))
    sns.histplot(
        data=data[data[target] == target_uniq[0]],
        x=predictor,
        kde=True,
        ax=axs[0, 0],
        color="teal",
    )

    axs[0, 1].set_title("Distribution of target for target=" + str(target_uniq[1]))
    sns.histplot(
        data=data[data[target] == target_uniq[1]],
        x=predictor,
        kde=True,
        ax=axs[0, 1],
        color="orange",
    )

    axs[1, 0].set_title("Boxplot w.r.t target")
    sns.boxplot(data=data, x=target, y=predictor, ax=axs[1, 0], palette="gist_rainbow")

    axs[1, 1].set_title("Boxplot (without outliers) w.r.t target")
    sns.boxplot(
        data=data,
        x=target,
        y=predictor,
        ax=axs[1, 1],
        showfliers=False,
        palette="gist_rainbow",
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Univariate Analysis

# %%
histogram_boxplot(data, 'Customer_Age')
plt.show()

# %% [markdown]
# Plot shows normal distribution and not many outliers are seen

# %%
histogram_boxplot(data, 'Months_on_book')
plt.show()

# %%
data['Months_on_book'].value_counts(1).head(1)
# Out:
# Months_on_book
# 36    0.243211
# Name: proportion, dtype: float64

# %% [markdown]
# Plot shows normal distribution
# 24% of the entries have 36 Months_on_book.

# %%
histogram_boxplot(data, 'Credit_Limit')
plt.show()

# %% [markdown]
# Distribution is right skewed with many outliers

# %%
histogram_boxplot(data, 'Total_Revolving_Bal')
plt.show()

# %% [markdown]
# The distribution of Total_Revolving_Bal is slightly left-skewed, with a median of approximately 1250 and a mean slightly lower. This suggests that a subset of customers maintain a zero balance, likely due to consistent monthly repayments

# %%
histogram_boxplot(data, 'Avg_Open_To_Buy')
plt.show()

# %% [markdown]
# Plot shows the distribution is right skewed. Many outliers are present.

# %%
histogram_boxplot(data, 'Total_Amt_Chng_Q4_Q1')
plt.show()

# %% [markdown]
# Plot shows normal distribution. There seems to be few outliers.

# %%
histogram_boxplot(data, 'Total_Trans_Amt')
plt.show()

# %% [markdown]
# Distribution is right skewed with many outliers. All customers have used their card.

# %%
histogram_boxplot(data, 'Total_Trans_Ct')
plt.show()

# %% [markdown]
# plot shpws the data is almost normally distributed with median approx equal to mean.

# %%
histogram_boxplot(data, 'Total_Ct_Chng_Q4_Q1')
plt.show()

# %% [markdown]
#  data normally distributed with median of 0.6

# %%
histogram_boxplot(data, 'Avg_Utilization_Ratio')
plt.show()

# %% [markdown]
# Distribution is right skewed. No outliers are there

# %%
labeled_barplot(data, 'Attrition_Flag')

# %% [markdown]
# This is the target variable. The dataset seems to be imbalanced.

# %%
labeled_barplot(data, 'Dependent_count')

# %%
data['Dependent_count'].value_counts(1) #getting the percentage for each category
# Out:
# Dependent_count
# 3    0.269774
# 2    0.262170
# 1    0.181495
# 4    0.155426
# 0    0.089266
# 5    0.041868
# Name: proportion, dtype: float64

# %% [markdown]
# 26.9% of customers have 3 dependents.
# 26.2% of customers have 2 dependents.
# 18% of customers have 1 dependent.
# 15% of customers have 4 dependents.

# %%
labeled_barplot(data, 'Education_Level')
data['Education_Level'].value_counts(1)
# Out:
# Education_Level
# Graduate         0.363383
# High School      0.233852
# Uneducated       0.172746
# College          0.117681
# Post-Graduate    0.059944
# Doctorate        0.052393
# Name: proportion, dtype: float64

# %% [markdown]
# 36% of customers are graduated.
# 23% of customers have  high school diploma.
# 17% of customers are uneducated.

# %%
labeled_barplot(data, 'Income_Category')

data['Income_Category'].value_counts(1)
# Out:
# Income_Category
# Less than $40K    0.395008
# $40K - $60K       0.198558
# $80K - $120K      0.170272
# $60K - $80K       0.155519
# $120K +           0.080643
# Name: proportion, dtype: float64

# %% [markdown]
# 39% of customers are less than 40k.
# 19% of customers are between 40k - 60k.
# 17% of customers are between 80k - 120k.

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# #### Significant comparisons

# %%
distribution_plot_wrt_target(data, "Total_Trans_Amt", "Attrition_Flag")

# %% [markdown]
# Attrited customers exhibit lower overall transaction activity compared to existing customers. The median transaction amount for attrited customers is significantly lower at approximately $2500, and the distribution of spending is less dispersed, suggesting a more limited range of transaction values. Additionally, the maximum transaction amount observed for attrited customers is notably lower than that of existing customers.

# %%
distribution_plot_wrt_target(data, "Total_Trans_Ct", "Attrition_Flag")

# %% [markdown]
# Attrited customers exhibit a lower range of transaction counts compared to existing customers. The median and maximum values for 'Total_Trans_Ct' are significantly lower for attrited customers, suggesting a less active transaction history.

# %%
distribution_plot_wrt_target(data, "Total_Revolving_Bal", "Attrition_Flag")

# %% [markdown]
# The analysis suggests distinct spending patterns between existing and attrited customers. Existing customers tend to maintain a more consistent level of revolving balance, while attrited customers exhibit a more varied pattern, with a significant proportion having either very low or very high revolving balances.

# %%
distribution_plot_wrt_target(data, "Total_Ct_Chng_Q4_Q1", "Attrition_Flag")

# %% [markdown]
# While the maximum 'Total_Ct_Chng_Q4_Q1' is comparable between existing and attrited customers, the minimum value for existing customers is significantly higher. This suggests that existing customers exhibit a greater degree of consistency in their transaction behavior across quarters.

# %%
distribution_plot_wrt_target(data, "Total_Amt_Chng_Q4_Q1", "Attrition_Flag")

# %% [markdown]
# A key distinction between attrited and existing customers lies in their spending behavior across quarters. While both groups exhibit similar distributional patterns in 'Total_Amt_Chng_Q4_Q1', existing customers demonstrate a higher median value and a less pronounced lower bound, suggesting a greater propensity for increased spending compared to attrited customers.

# %% [markdown]
# ### Test Train split

# %%
# Independent variables dataset. Removal of target variable
X = data.drop('Attrition_Flag', axis=1)
# Target variable.
y = data['Attrition_Flag']

# %%
X_train, X_stage, y_train, y_stage = train_test_split(X, y, test_size=0.5, random_state=1, stratify=y)
X_val, X_test, y_val, y_test = train_test_split(X_stage, y_stage, test_size=0.4, random_state=1, stratify=y_stage)

# %%
print("-"*40)
print("Shape of Training Set : ", X_train.shape)
print("Shape of Validation Set", X_val.shape)
print("Shape of Test Set : ", X_test.shape)
print("-"*40)
print("Percentage of classes in training set:")
print(y_train.value_counts(normalize=True))
print("-"*40)
print("Percentage of classes in validation set:")
print(y_val.value_counts(normalize=True))
print("-"*40)
print("Percentage of classes in test set:")
print(y_test.value_counts(normalize=True))
print("-"*40)
# Out:
# ----------------------------------------
# Shape of Training Set :  (5063, 19)
# Shape of Validation Set (3038, 19)
# Shape of Test Set :  (2026, 19)
# ----------------------------------------
# Percentage of classes in training set:
# Attrition_Flag
# 1    0.839423
# 0    0.160577
# Name: proportion, dtype: float64
# ----------------------------------------
# Percentage of classes in validation set:
# Attrition_Flag
# 1    0.839368
# 0    0.160632
# Name: proportion, dtype: float64
# ----------------------------------------
# Percentage of classes in test set:
# Attrition_Flag
# 1    0.839092
# 0    0.160908
# Name: proportion, dtype: float64
# ----------------------------------------

# %% [markdown]
# Data ia split into train validation and test datasets. Model is trained with train dataset, and staged with validation dataset. For the best model, it is tested with test dataset.

# %% [markdown]
# ### Missing value treatment

# %%
X_train.isna().sum().sum() #missing values in training set
# Out:
# 1667

# %%
X_val.isna().sum().sum() #missing values in validation set
# Out:
# 1031

# %%
X_test.isna().sum().sum() #missing values in test set
# Out:
# 682

# %%
#imputation strategy
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
col_to_be_imputed = ['Education_Level', 'Income_Category', 'Marital_Status']

# %%
#Implementation of imputing
# train columns.
X_train[col_to_be_imputed] = imputer.fit_transform(X_train[col_to_be_imputed])
# val columns.
X_val[col_to_be_imputed] = imputer.fit_transform(X_val[col_to_be_imputed])
# test columns.
X_test[col_to_be_imputed] = imputer.fit_transform(X_test[col_to_be_imputed])

# %%
X_train.isna().sum().sum() #missing values in training set
# Out:
# 0

# %%
X_val.isna().sum().sum() #missing values in training set
# Out:
# 0

# %%
X_test.isna().sum().sum() #missing values in training set
# Out:
# 0

# %% [markdown]
# All missing values are handled.

# %% [markdown]
# #### Encoding categorical variables

# %%
X_train = pd.get_dummies(X_train, columns=['Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category'], drop_first=True)

X_val = pd.get_dummies(X_val, columns=['Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category'], drop_first=True)

X_test = pd.get_dummies(X_test, columns=['Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category'], drop_first=True)

# %%
print(X_train.shape,X_val.shape,X_test.shape)
# Out:
# (5063, 29) (3038, 29) (2026, 29)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5063 entries, 5930 to 10034
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Customer_Age                    5063 non-null   int64
#  1   Dependent_count                 5063 non-null   int64
#  2   Months_on_book                  5063 non-null   int64
#  3   Total_Relationship_Count        5063 non-null   int64
#  4   Months_Inactive_12_mon          5063 non-null   int64
#  5   Contacts_Count_12_mon           5063 non-null   int64
#  6   Credit_Limit                    5063 non-null   float64
#  7   Total_Revolving_Bal             5063 non-null   int64
#  8   Avg_Open_To_Buy                 5063 non-null   float64
#  9   Total_Amt_Chng_Q4_Q1            5063 non-null   float64
#  10  Total_Trans_Amt                 5063 non-null   int64
#  11  Total_Trans_Ct                  5063 non-null   int64
# ...

# %%
X_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3038 entries, 9952 to 1898
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Customer_Age                    3038 non-null   int64
#  1   Dependent_count                 3038 non-null   int64
#  2   Months_on_book                  3038 non-null   int64
#  3   Total_Relationship_Count        3038 non-null   int64
#  4   Months_Inactive_12_mon          3038 non-null   int64
#  5   Contacts_Count_12_mon           3038 non-null   int64
#  6   Credit_Limit                    3038 non-null   float64
#  7   Total_Revolving_Bal             3038 non-null   int64
#  8   Avg_Open_To_Buy                 3038 non-null   float64
#  9   Total_Amt_Chng_Q4_Q1            3038 non-null   float64
#  10  Total_Trans_Amt                 3038 non-null   int64
#  11  Total_Trans_Ct                  3038 non-null   int64
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2026 entries, 3043 to 215
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Customer_Age                    2026 non-null   int64
#  1   Dependent_count                 2026 non-null   int64
#  2   Months_on_book                  2026 non-null   int64
#  3   Total_Relationship_Count        2026 non-null   int64
#  4   Months_Inactive_12_mon          2026 non-null   int64
#  5   Contacts_Count_12_mon           2026 non-null   int64
#  6   Credit_Limit                    2026 non-null   float64
#  7   Total_Revolving_Bal             2026 non-null   int64
#  8   Avg_Open_To_Buy                 2026 non-null   float64
#  9   Total_Amt_Chng_Q4_Q1            2026 non-null   float64
#  10  Total_Trans_Amt                 2026 non-null   int64
#  11  Total_Trans_Ct                  2026 non-null   int64
# ...

# %% [markdown]
# ### Model Building

# %%
# Defining a function to compute different metrics to check performance of a classification model built using sklearn.
def model_performance_classification_sklearn(model, predictors, target):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    """

    # Predicting using the independent variables.
    pred = model.predict(predictors)

    acc = accuracy_score(target, pred)  # To compute Accuracy.
    recall = recall_score(target, pred)  # To compute Recall.
    precision = precision_score(target, pred)  # To compute Precision.
    f1 = f1_score(target, pred)  # To compute F1-score.

    # Creating a dataframe of metrics.
    df_perf = pd.DataFrame(
        {
            "Accuracy": acc,
            "Recall": recall,
            "Precision": precision,
            "F1": f1

        },
        index=[0],
    )

    return df_perf

# %%
# Defining a function to create a confusion matrix to check TP, FP, TN, adn FN values.
def confusion_matrix_sklearn(model, predictors, target):
    """
    To plot the confusion_matrix with percentages

    model: classifier
    predictors: independent variables
    target: dependent variable
    """
    # Predicting using the independent variables.
    y_pred = model.predict(predictors)
    # Creating the confusion matrix.
    cm = confusion_matrix(target, y_pred)
    labels = np.asarray(
        [
            ["{0:0.0f}".format(item) + "\n{0:.2%}".format(item / cm.flatten().sum())]
            for item in cm.flatten()
        ]
    ).reshape(2, 2)

    # Plotting the confusion matrix.
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=labels, fmt="")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %%
model_list = []

model_list.append(("Bagging", BaggingClassifier(random_state=1)))
model_list.append(("Random forest", RandomForestClassifier(random_state=1)))
model_list.append(("AdaBoost", AdaBoostClassifier(random_state=1)))
model_list.append(("GradientBoost", GradientBoostingClassifier(random_state=1)))
model_list.append(("XGBoost", XGBClassifier(random_state=1)))


model_list
# Out:
# [('Bagging', BaggingClassifier(random_state=1)),
#  ('Random forest', RandomForestClassifier(random_state=1)),
#  ('AdaBoost', AdaBoostClassifier(random_state=1)),
#  ('GradientBoost', GradientBoostingClassifier(random_state=1)),
#  ('XGBoost',
#   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %%
print("\n" "model Performance on training set:" "\n")
for name, model in model_list:
    model.fit(X_train, y_train)
    scores = precision_score(y_train, model.predict(X_train))
    print("{}: {}".format(name, scores))

# Printing model performance scores on validation data.
print("\n" "Model Performance on validation set:" "\n")
for name, model in model_list:
    model.fit(X_train, y_train)
    scores_val = precision_score(y_val, model.predict(X_val))
    print("{}: {}".format(name, scores_val))
# Out:
# model Performance on training set:
#
# Bagging: 0.9974135904067717
# Random forest: 1.0
# AdaBoost: 0.9716080986734932
# GradientBoost: 0.9827786828019549
# XGBoost: 1.0
#
# Model Performance on validation set:
#
# Bagging: 0.9675907848496681
# Random forest: 0.9563898369359121
# AdaBoost: 0.9640232108317215
# GradientBoost: 0.9670371789957838
# XGBoost: 0.9748159628051143

# %% [markdown]
# Above model is built using the original dataset.
#
# From the univariate analysis, we got to know that the dataset is imbalanced. Hence we will have to up sample or downsample for avoiding biases.

# %% [markdown]
# #### Over sampling technique: Model building

# %%
sm = SMOTE(sampling_strategy=1, k_neighbors=5, random_state=1) #sm is synthetic minority
X_train_oversampled, y_train_oversampled = sm.fit_resample(X_train, y_train)

# %%
models_oversampled = []  # Empty list to store all the models.

# Appending models into the list
models_oversampled.append(("Bagging", BaggingClassifier(random_state=1)))
models_oversampled.append(("Random forest", RandomForestClassifier(random_state=1)))
models_oversampled.append(("AdaBoost", AdaBoostClassifier(random_state=1)))
models_oversampled.append(("GradientBoost", GradientBoostingClassifier(random_state=1)))
models_oversampled.append(("XGBoost", XGBClassifier(random_state=1)))

models_oversampled
# Out:
# [('Bagging', BaggingClassifier(random_state=1)),
#  ('Random forest', RandomForestClassifier(random_state=1)),
#  ('AdaBoost', AdaBoostClassifier(random_state=1)),
#  ('GradientBoost', GradientBoostingClassifier(random_state=1)),
#  ('XGBoost',
#   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, device=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
# ...

# %%
# Printing model performance scores on training data.
print("\n" "Model Performance on training set:" "\n")
for name, model in models_oversampled:
    model.fit(X_train_oversampled, y_train_oversampled)
    scores = precision_score(y_train_oversampled, model.predict(X_train_oversampled))
    print("{}: {}".format(name, scores))
# Printing model performance scores on validation data.
print("\n" "Model Performance on validation set:" "\n")
for name, model in models_oversampled:
    model.fit(X_train_oversampled, y_train_oversampled)
    scores_val = precision_score(y_val, model.predict(X_val))
    print("{}: {}".format(name, scores_val))
# Out:
# Model Performance on training set:
#
# Bagging: 0.9995274102079396
# Random forest: 1.0
# AdaBoost: 0.9673731840914503
# GradientBoost: 0.981301775147929
# XGBoost: 1.0
#
# Model Performance on validation set:
#
# Bagging: 0.9746172441579372
# Random forest: 0.9702194357366771
# AdaBoost: 0.9739895958383353
# GradientBoost: 0.9747335175681011
# XGBoost: 0.9808369182635901

# %% [markdown]
# ### Undersampling technique: Model building

# %%
rus = RandomUnderSampler(random_state=1, sampling_strategy=1) #rus is random undersampler
X_train_under, y_train_under = rus.fit_resample(X_train, y_train)

# %%
models_under = []  # Empty list to store all the models.

# Appending models into the list.
models_under.append(("Bagging", BaggingClassifier(random_state=1)))
models_under.append(("Random forest", RandomForestClassifier(random_state=1)))
models_under.append(("AdaBoost", AdaBoostClassifier(random_state=1)))
models_under.append(("GradientBoost", GradientBoostingClassifier(random_state=1)))
models_under.append(("XGBoost", XGBClassifier(random_state=1)))

# Printing model performance scores on training data.
print("\n" "Model Performance on training set:" "\n")
for name, model in models_under:
    model.fit(X_train_under, y_train_under)
    scores = precision_score(y_train_under, model.predict(X_train_under))
    print("{}: {}".format(name, scores))

# Printing model performance scores on validation data.
print("\n" "Model Performance on validation set:" "\n")
for name, model in models_under:
    model.fit(X_train_under, y_train_under)
    scores_val = precision_score(y_val, model.predict(X_val))
    print("{}: {}".format(name, scores_val))
# Out:
# Model Performance on training set:
#
# Bagging: 0.9987593052109182
# Random forest: 1.0
# AdaBoost: 0.9650436953807741
# GradientBoost: 0.9851851851851852
# XGBoost: 1.0
#
# Model Performance on validation set:
#
# Bagging: 0.9819587628865979
# Random forest: 0.9886839899413243
# AdaBoost: 0.9878304657994125
# GradientBoost: 0.9892517569243489
# XGBoost: 0.9860426929392446

# %% [markdown]
# ### Hyperparameter tuning

# %% [markdown]
# #### Models built on original data

# %% [markdown]
# 1. XGBoost

# %%
# Defining the model.
XGB_originaldata = XGBClassifier(random_state=1)

# Creating the parameter grid to pass in RandomSearchCV.
param_grid = {
            'n_estimators':np.arange(50,110,25),
            'scale_pos_weight':[1,2,5],
            'learning_rate':[0.01,0.1,0.05],
            'gamma':[1,3],
            'subsample':[0.7,0.9]
}

# Defining the scorer.
scorer = make_scorer(precision_score)

# Calling RandomizedSearchCV.
randomized_cv = RandomizedSearchCV(estimator=XGB_originaldata, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

# Fitting the parameters in RandomizedSearchCV.
randomized_cv.fit(X_train,y_train)

# Printing the best parameters from from the RandomizedSearchCV.
print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'subsample': 0.7, 'scale_pos_weight': 1, 'n_estimators': 100, 'learning_rate': 0.05, 'gamma': 1} with CV score=0.9719966214762692:

# %%
#Tuned data model
XGB_originaldata_tuned = XGBClassifier(
    random_state=1,
    subsample=0.7,
    scale_pos_weight=1,
    n_estimators=100,
    learning_rate=0.05,
    gamma=1)

# Fitting the model to the original training data.
XGB_originaldata_tuned.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=1, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=1, ...)

# %%
model_performance_classification_sklearn(XGB_originaldata_tuned, X_train, y_train) #Performance of model
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.990519  0.996471   0.992268  0.994365

# %%
XGB_originaldata_tuned_train_scores = model_performance_classification_sklearn(XGB_originaldata_tuned, X_train, y_train) #For the comparison of models

# %%
#Confusion matrix
confusion_matrix_sklearn(XGB_originaldata_tuned, X_train, y_train)
plt.show();

# %%
model_performance_classification_sklearn(XGB_originaldata_tuned, X_val, y_val)
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.960829  0.986275    0.96768  0.976889

# %%
XGB_originaldata_tuned_val_scores = model_performance_classification_sklearn(XGB_originaldata_tuned, X_val, y_val)

# %%
#Confusion matrix
confusion_matrix_sklearn(XGB_originaldata_tuned, X_val, y_val)
plt.show();

# %% [markdown]
# 2. Gradient Boost

# %%
# Defining the model.
GB_Orgdata = GradientBoostingClassifier(random_state=1)

# Creating the parameter grid to pass in RandomSearchCV.
param_grid={"init": [AdaBoostClassifier(random_state=1),DecisionTreeClassifier(random_state=1)],
            "n_estimators": np.arange(50,110,25),
            "learning_rate": [0.01,0.1,0.05],
            "subsample":[0.7,0.9],
            "max_features":[0.5,0.7,1],
}
# Defining the scorer.
scorer = make_scorer(precision_score)

# Calling RandomizedSearchCV.
randomized_cv = RandomizedSearchCV(estimator=GB_Orgdata, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

# Fitting the parameters in RandomizedSearchCV.
randomized_cv.fit(X_train,y_train)

# Printing the best parameters from from the RandomizedSearchCV.
print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

GB_Orgdata_tuned = GradientBoostingClassifier(
    random_state=1,
    subsample=0.7,
    n_estimators=100,
    max_features=0.7,
    learning_rate=0.05,
    init=DecisionTreeClassifier(random_state=1))

# Fitting the model to the original training data.
GB_Orgdata_tuned.fit(X_train, y_train)
# Out:
# Best parameters are {'subsample': 0.7, 'n_estimators': 100, 'max_features': 0.7, 'learning_rate': 0.05, 'init': DecisionTreeClassifier(random_state=1)} with CV score=0.9635312910330839:
# GradientBoostingClassifier(init=DecisionTreeClassifier(random_state=1),
#                            learning_rate=0.05, max_features=0.7, random_state=1,
#                            subsample=0.7)

# %%
GB_Orgdata_tuned_train_scores = model_performance_classification_sklearn(GB_Orgdata_tuned, X_train, y_train)

# %%
confusion_matrix_sklearn(GB_Orgdata_tuned, X_train, y_train)
plt.show();

# %%
model_performance_classification_sklearn(GB_Orgdata_tuned, X_val, y_val)
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.938446  0.964706   0.962065  0.963384

# %%
GB_Orgdata_tuned_val_scores = model_performance_classification_sklearn(GB_Orgdata_tuned, X_val, y_val)

# %%
confusion_matrix_sklearn(GB_Orgdata_tuned, X_val, y_val)
plt.show();

# %% [markdown]
# 3. Ada boost

# %%
# Defining the model.
AB_Orgdata = AdaBoostClassifier(random_state=1)

# Creating the parameter grid to pass in RandomSearchCV.
param_grid = {
          "n_estimators": np.arange(50,110,25),
          "learning_rate": [0.01,0.1,0.05],
          
          "estimator": [
        DecisionTreeClassifier(max_depth=2, random_state=1),
        DecisionTreeClassifier(max_depth=3, random_state=1),]
}

# Defining the scorer.
scorer = make_scorer(precision_score)

# Calling RandomizedSearchCV.
randomized_cv = RandomizedSearchCV(estimator=AB_Orgdata, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

# Fitting parameters in RandomizedSearchCV.
randomized_cv.fit(X_train,y_train)

# Printing the best parameters from from the RandomizedSearchCV.
print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))

AB_Orgdata_tuned = AdaBoostClassifier(
    random_state=1,
    n_estimators=100,
    learning_rate=0.1,
    estimator=DecisionTreeClassifier(max_depth=3, random_state=1))

# Fitting the model to the original training data.
AB_Orgdata_tuned.fit(X_train, y_train)
# Out:
# Best parameters are {'n_estimators': 100, 'learning_rate': 0.1, 'estimator': DecisionTreeClassifier(max_depth=3, random_state=1)} with CV score=0.9749406645025787:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=3,
#                                                     random_state=1),
#                    learning_rate=0.1, n_estimators=100, random_state=1)

# %%
model_performance_classification_sklearn(AB_Orgdata_tuned, X_train, y_train)
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.990717  0.996706    0.99227  0.994483

# %%
AB_Orgdata_tuned_train_scores = model_performance_classification_sklearn(AB_Orgdata_tuned, X_train, y_train)

# %%
confusion_matrix_sklearn(AB_Orgdata_tuned, X_train, y_train)
plt.show();

# %%
model_performance_classification_sklearn(AB_Orgdata_tuned, X_val, y_val)
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.964121  0.991373    0.96673  0.978896

# %%
AB_Orgdata_tuned_val_scores = model_performance_classification_sklearn(AB_Orgdata_tuned, X_val, y_val)

# %%
confusion_matrix_sklearn(AB_Orgdata_tuned, X_val, y_val)
plt.show();

# %% [markdown]
# #### Models built on oversampled data

# %% [markdown]
# 1. XG Boost

# %%
# Defining the model.
XGB_oversampled = XGBClassifier(random_state=1)

# Creating the parameter grid to pass in RandomSearchCV.
param_grid={'n_estimators':np.arange(50,110,25),
            'scale_pos_weight':[1,2,5],
            'learning_rate':[0.01,0.1,0.05],
            'gamma':[1,3],
            'subsample':[0.7,0.9]
}

# Defining the scorer.
scorer = make_scorer(precision_score)

# Calling RandomizedSearchCV.
randomized_cv = RandomizedSearchCV(estimator=XGB_oversampled, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

# Fitting the parameters in RandomizedSearchCV.
randomized_cv.fit(X_train_oversampled,y_train_oversampled)

# Printing the best parameters from from the RandomizedSearchCV.
print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'subsample': 0.7, 'scale_pos_weight': 1, 'n_estimators': 100, 'learning_rate': 0.05, 'gamma': 1} with CV score=0.9754293955482766:

# %%
# Creating the tuned model with the best parameters found in RandomizedSearchCV.
XGB_oversampled_tuned = XGBClassifier(
    random_state=1,
    subsample=0.7,
    scale_pos_weight=1,
    n_estimators=100,
    learning_rate=0.05,
    gamma=1)

# Fitting the tuned model to the oversampled traning data.
XGB_oversampled_tuned.fit(X_train_oversampled, y_train_oversampled)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=1, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=1, ...)

# %%
XGB_oversampled_tuned_train_scores = model_performance_classification_sklearn(XGB_oversampled_tuned, X_train_oversampled, y_train_oversampled)
XGB_oversampled_tuned_val_scores = model_performance_classification_sklearn(XGB_oversampled_tuned, X_val, y_val)

# %%
confusion_matrix_sklearn(XGB_oversampled_tuned, X_train_oversampled, y_train_oversampled)
plt.show();
confusion_matrix_sklearn(XGB_oversampled_tuned, X_train_oversampled, y_train_oversampled)
plt.show();

# %% [markdown]
# 2. Ada boost

# %%
# Defining the model.
AB_oversampled = AdaBoostClassifier(random_state=1)

# Creating the parameter grid to pass in RandomSearchCV.
param_grid = {
          "n_estimators": np.arange(50,110,25),
          "learning_rate": [0.01,0.1,0.05],
          "estimator": [
        DecisionTreeClassifier(max_depth=2, random_state=1),
        DecisionTreeClassifier(max_depth=3, random_state=1),]
}

# Defining the scorer.
scorer = make_scorer(precision_score)

# Calling RandomizedSearchCV.
randomized_cv = RandomizedSearchCV(estimator=AB_oversampled, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

# Fitting parameters in RandomizedSearchCV.
randomized_cv.fit(X_train_over,y_train_over)

# Printing the best parameters from from the RandomizedSearchCV.
print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 75, 'learning_rate': 0.1, 'estimator': DecisionTreeClassifier(max_depth=3, random_state=1)} with CV score=0.9636950966675997:

# %%
AB_oversampled_tuned = AdaBoostClassifier(
    random_state=1,
    n_estimators=100,
    learning_rate=0.1,
    estimator=DecisionTreeClassifier(max_depth=3, random_state=1))

# Fitting the model to the oversampled training data.
AB_oversampled_tuned.fit(X_train_oversampled, y_train_oversampled)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=3,
#                                                     random_state=1),
#                    learning_rate=0.1, n_estimators=100, random_state=1)

# %%
AB_oversampled_tuned_train_scores = model_performance_classification_sklearn(AB_oversampled_tuned, X_train_oversampled, y_train_oversampled)
AB_oversampled_tuned_val_scores = model_performance_classification_sklearn(AB_oversampled_tuned, X_val, y_val)

# %%
confusion_matrix_sklearn(AB_oversampled_tuned, X_train_oversampled, y_train_oversampled)
plt.show();
confusion_matrix_sklearn(AB_oversampled_tuned, X_val, y_val)
plt.show();

# %% [markdown]
# 3. Gradient boost

# %%
 #Defining the model.
GB_oversampled = GradientBoostingClassifier(random_state=1)

# Creating the parameter grid to pass in RandomSearchCV.
param_grid={"init": [AdaBoostClassifier(random_state=1),DecisionTreeClassifier(random_state=1)],
            "n_estimators": np.arange(50,110,25),
            "learning_rate": [0.01,0.1,0.05],
            "subsample":[0.7,0.9],
            "max_features":[0.5,0.7,1],
}
# Defining the scorer.
scorer = make_scorer(precision_score)

# Calling RandomizedSearchCV.
randomized_cv = RandomizedSearchCV(estimator=GB_oversampled, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

# Fitting the parameters in RandomizedSearchCV.
randomized_cv.fit(X_train_oversampled,y_train_oversampled)

# Printing the best parameters from from the RandomizedSearchCV.
print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'subsample': 0.7, 'n_estimators': 100, 'max_features': 0.7, 'learning_rate': 0.05, 'init': DecisionTreeClassifier(random_state=1)} with CV score=0.9489865351392494:

# %%
GB_oversampled_tuned = GradientBoostingClassifier(
    random_state=1,
    subsample=0.7,
    n_estimators=100,
    max_features=0.7,
    learning_rate=0.05,
    init=DecisionTreeClassifier(random_state=1))

# Fitting the model to the original training data.
GB_oversampled_tuned.fit(X_train_over, y_train_over)
# Out:
# GradientBoostingClassifier(init=DecisionTreeClassifier(random_state=1),
#                            learning_rate=0.05, max_features=0.7, random_state=1,
#                            subsample=0.7)

# %%
GB_oversampled_tuned_train_scores = model_performance_classification_sklearn(GB_oversampled_tuned, X_train_oversampled, y_train_oversampled)
GB_oversampled_tuned_val_scores = model_performance_classification_sklearn(GB_oversampled_tuned, X_val, y_val)

# %%
confusion_matrix_sklearn(GB_oversampled_tuned, X_train_oversampled, y_train_oversampled)
plt.show();
confusion_matrix_sklearn(GB_oversampled_tuned, X_val, y_val)
plt.show();

# %% [markdown]
# #### Models built on under sampled data

# %% [markdown]
# 1. Gradient boost

# %%
# Defining the model.
GB_undersampled = GradientBoostingClassifier(random_state=1)

# Creating the parameter grid to pass in RandomSearchCV.
param_grid={"init": [AdaBoostClassifier(random_state=1),DecisionTreeClassifier(random_state=1)],
            "n_estimators": np.arange(50,110,25),
            "learning_rate": [0.01,0.1,0.05],
            "subsample":[0.7,0.9],
            "max_features":[0.5,0.7,1],
}
# Defining the scorer.
scorer = make_scorer(precision_score)

# Calling RandomizedSearchCV.
randomized_cv = RandomizedSearchCV(estimator=GB_undersampled, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

# Fitting the parameters in RandomizedSearchCV.
randomized_cv.fit(X_train_under,y_train_under)

# Printing the best parameters from from the RandomizedSearchCV.
print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'subsample': 0.7, 'n_estimators': 100, 'max_features': 0.7, 'learning_rate': 0.05, 'init': DecisionTreeClassifier(random_state=1)} with CV score=0.8892064036527325:

# %%
GB_undersampled_tuned = GradientBoostingClassifier(
    random_state=1,
    subsample=0.7,
    n_estimators=100,
    max_features=0.7,
    learning_rate=0.05,
    init=DecisionTreeClassifier(random_state=1))

# Fitting the model to the undersampled training data.
GB_undersampled_tuned.fit(X_train_under, y_train_under)
# Out:
# GradientBoostingClassifier(init=DecisionTreeClassifier(random_state=1),
#                            learning_rate=0.05, max_features=0.7, random_state=1,
#                            subsample=0.7)

# %%
GB_undersampled_tuned_train_scores = model_performance_classification_sklearn(GB_undersampled_tuned, X_train_under, y_train_under)
GB_undersampled_tuned_val_scores = model_performance_classification_sklearn(GB_undersampled_tuned, X_val, y_val)

# %%
confusion_matrix_sklearn(GB_undersampled_tuned, X_train_under, y_train_under)
plt.show();
confusion_matrix_sklearn(GB_undersampled_tuned, X_val, y_val)
plt.show();

# %% [markdown]
# 2. Random forest

# %%
# Defining the model.
RF_under = RandomForestClassifier(random_state=1)

# Creating the parameter grid to pass in RandomSearchCV.
param_grid={
    "n_estimators": [50,110,25],
    "min_samples_leaf": np.arange(1, 4),
    "max_features": [np.arange(0.3, 0.6, 0.1),'sqrt'],
    "max_samples": np.arange(0.4, 0.7, 0.1)
}

# Defining the scorer.
scorer = make_scorer(precision_score)

# Calling RandomizedSearchCV.
randomized_cv = RandomizedSearchCV(estimator=RF_under, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

# Fitting the parameters in RandomizedSearchCV.
randomized_cv.fit(X_train_under,y_train_under)

# Printing the best parameters from from the RandomizedSearchCV.
print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 110, 'min_samples_leaf': 1, 'max_samples': 0.6, 'max_features': 'sqrt'} with CV score=0.9320736819168681:

# %%
# Creating the tuned model with the best parameters found in RandomizedSearchCV.
RF_under_tuned = RandomForestClassifier(
    random_state=1,
    n_estimators=110,
    min_samples_leaf=1,
    max_samples=0.6,
    max_features='sqrt')

# Fitting the tuned model to the undersampled traning data.
RF_under_tuned.fit(X_train_under, y_train_under)
# Out:
# RandomForestClassifier(max_samples=0.6, n_estimators=110, random_state=1)

# %%
RF_under_tuned_train_scores = model_performance_classification_sklearn(RF_under_tuned, X_train_under, y_train_under)
RF_under_tuned_val_scores = model_performance_classification_sklearn(RF_under_tuned, X_val, y_val)

# %%
confusion_matrix_sklearn(RF_under_tuned, X_train_under, y_train_under)
plt.show();
confusion_matrix_sklearn(RF_under_tuned, X_val, y_val)
plt.show();

# %% [markdown]
# 3. Ada boost

# %%
# Defining the model.
AB_under = AdaBoostClassifier(random_state=1)

# Creating the parameter grid to pass in RandomSearchCV.
param_grid = {
    "n_estimators": np.arange(50,110,25),
    "learning_rate": [0.01,0.1,0.05],
    "estimator": [
        DecisionTreeClassifier(max_depth=2, random_state=1),
        DecisionTreeClassifier(max_depth=3, random_state=1),
    ],
}

# Defining the scorer.
scorer = make_scorer(precision_score)

# Calling RandomizedSearchCV.
randomized_cv = RandomizedSearchCV(estimator=AB_under, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

# Fitting the parameters in RandomizedSearchCV.
randomized_cv.fit(X_train_under,y_train_under)

# Printing the best parameters from from the RandomizedSearchCV.
print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 75, 'learning_rate': 0.1, 'estimator': DecisionTreeClassifier(max_depth=2, random_state=1)} with CV score=0.952813496431437:

# %%
# Creating the tuned model with the best parameters found in RandomizedSearchCV.
AB_under_tuned = AdaBoostClassifier(
    random_state=1,
    n_estimators=75,
    learning_rate=0.1,
    estimator=DecisionTreeClassifier(max_depth=2, random_state=1))

# Fitting the tuned model to the undersampled traning data.
AB_under_tuned.fit(X_train_under, y_train_under)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=2,
#                                                     random_state=1),
#                    learning_rate=0.1, n_estimators=75, random_state=1)

# %%
AB_under_tuned_train_scores = model_performance_classification_sklearn(AB_under_tuned, X_train_under, y_train_under)
AB_under_tuned_val_scores = model_performance_classification_sklearn(AB_under_tuned, X_val, y_val)

# %%
confusion_matrix_sklearn(AB_under_tuned, X_train_under, y_train_under)
plt.show();
confusion_matrix_sklearn(AB_under_tuned, X_val, y_val)
plt.show();

# %% [markdown]
# ### Model comparison

# %%
models_train_comp_df = pd.concat(
    [
        XGB_originaldata_tuned_train_scores.T,
        GB_Orgdata_tuned_train_scores.T,
        AB_Orgdata_tuned_train_scores.T,
        XGB_oversampled_tuned_train_scores.T,
        AB_oversampled_tuned_train_scores.T,
        GB_oversampled_tuned_train_scores.T,
        GB_undersampled_tuned_train_scores.T,
        RF_under_tuned_train_scores.T,
        AB_under_tuned_train_scores.T,
    ],
    axis=1,
)
models_train_comp_df.columns = [
      "XGBoost trained with Original data",
      "Gradient boosting trained with Original data",
      "AdaBoost trained with Original data",
      "XGBoost trained with Oversampled data",
      "AdaBoost trained with Oversampled data",
      "Gradient boosting trained with Oversampled data",
      "Gradient boosting trained with Undersampled data",
      "Random Forest trained with Undersampled data",
      "AdaBoost trained with Undersampled data"
]
print("Training performance comparison:")
models_train_comp_df
# Out:
# Training performance comparison:
#            XGBoost trained with Original data  \
# Accuracy                             0.990519
# Recall                               0.996471
# Precision                            0.992268
# F1                                   0.994365
#
#            Gradient boosting trained with Original data  \
# Accuracy                                            1.0
# Recall                                              1.0
# Precision                                           1.0
# F1                                                  1.0
#
#            AdaBoost trained with Original data  \
# Accuracy                              0.990717
# Recall                                0.996706
# Precision                             0.992270
# F1                                    0.994483
#
#            XGBoost trained with Oversampled data  \
# Accuracy                                0.990235
# Recall                                  0.986824
# ...

# %%
models_val_comp_df = pd.concat(
    [
        XGB_originaldata_tuned_val_scores.T,
        GB_Orgdata_tuned_val_scores.T,
        AB_Orgdata_tuned_val_scores.T,
        XGB_oversampled_tuned_val_scores.T,
        AB_oversampled_tuned_val_scores.T,
        GB_oversampled_tuned_val_scores.T,
        GB_undersampled_tuned_val_scores.T,
        RF_under_tuned_val_scores.T,
        AB_under_tuned_val_scores.T,
    ],
    axis=1,
)
models_val_comp_df.columns = [
      "XGBoost trained with Original data",
      "Gradient boosting trained with Original data",
      "AdaBoost trained with Original data",
      "XGBoost trained with Oversampled data",
      "AdaBoost trained with Oversampled data",
      "Gradient boosting trained with Oversampled data",
      "Gradient boosting trained with Undersampled data",
      "Random Forest trained with Undersampled data",
      "AdaBoost trained with Undersampled data"
]
print("Validation performance comparison:")
models_val_comp_df
# Out:
# Validation performance comparison:
#            XGBoost trained with Original data  \
# Accuracy                             0.960829
# Recall                               0.986275
# Precision                            0.967680
# F1                                   0.976889
#
#            Gradient boosting trained with Original data  \
# Accuracy                                       0.938446
# Recall                                         0.964706
# Precision                                      0.962065
# F1                                             0.963384
#
#            AdaBoost trained with Original data  \
# Accuracy                              0.964121
# Recall                                0.991373
# Precision                             0.966730
# F1                                    0.978896
#
#            XGBoost trained with Oversampled data  \
# Accuracy                                0.956550
# Recall                                  0.970588
# ...

# %% [markdown]
# 3 models with highest precision is chosen to test the model with test data

# %%
RF_under_tuned_test_scores = model_performance_classification_sklearn(RF_under_tuned, X_test, y_test)
AB_under_tuned_test_scores = model_performance_classification_sklearn(AB_under_tuned, X_test, y_test)
AB_oversampled_tuned_test_scores = model_performance_classification_sklearn(AB_oversampled_tuned, X_test, y_test)

# %%
#Performance comparison
models_test_comp_df = pd.concat(
    [
        RF_under_tuned_test_scores.T,
        AB_under_tuned_test_scores.T,
        AB_oversampled_tuned_test_scores.T,
    ],
    axis=1,
)
models_test_comp_df.columns = [
      "Random Forest trained with Undersampled data",
      "AdaBoost trained with Undersampled data",
      "AdaBoost trained with Oversampled data"
]
print("Test performance comparison:")
models_test_comp_df
# Out:
# Test performance comparison:
#            Random Forest trained with Undersampled data  \
# Accuracy                                       0.935341
# Recall                                         0.937059
# Precision                                      0.985158
# F1                                             0.960506
#
#            AdaBoost trained with Undersampled data  \
# Accuracy                                  0.937808
# Recall                                    0.937647
# Precision                                 0.987608
# F1                                        0.961979
#
#            AdaBoost trained with Oversampled data
# Accuracy                                 0.966436
# Recall                                   0.981765
# Precision                                0.978312
# F1                                       0.980035

# %% [markdown]
# Model with highest precision is AdaBoost trained with under sampled data.

# %%
final_model = AB_under_tuned
model_performance_classification_sklearn(final_model, X_test, y_test)
# Out:
#    Accuracy    Recall  Precision        F1
# 0  0.937808  0.937647   0.987608  0.961979

# %%
confusion_matrix_sklearn(final_model, X_test, y_test)
plt.show();

# %% [markdown]
# By prioritizing the maximization of Precision, the model effectively minimizes the occurrence of False Positives (FP). FP instances arise when the model erroneously predicts that a customer will not churn, while in reality, they do. Minimizing FPs is crucial in this context as each instance represents a potential customer lost due to an incorrect prediction.

# %%
#Feature importance


feature_names = X_train.columns
importances =  final_model.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(12, 12))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], color="violet", align="center")
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()

# %% [markdown]
# ## Insights and Recommendations:

# %% [markdown]
# 1. Spending Patterns: Attrited customers exhibit lower spending frequency and volume compared to active customers. Encouraging increased spending activity among existing customers is crucial for customer retention.
# 2. Revolving Balance: Extreme revolving balances pose a risk of customer attrition. Customers with very low balances may be more likely to close their accounts due to infrequent usage, while those with excessively high balances may be more susceptible to financial difficulties and potential default. A moderate revolving balance is ideal, allowing for consistent interest income for the bank while maintaining customer affordability and reducing the risk of attrition.
# 3. Seasonal Spending: The analysis suggests that existing customers tend to increase their spending later in the year, as evidenced by the higher 'Total_Ct_Chng_Q4_Q1' values. In contrast, attrited customers may exhibit more sporadic or reactive spending behavior, potentially driven by financial necessity rather than consistent usage.
# 4. Product Usage: Customers with a single or two bank products demonstrate a higher propensity for attrition compared to those with a more diverse product portfolio (three or more products). To enhance customer retention, the bank should focus on strategies to deepen customer relationships by encouraging the adoption of additional banking products.
